# %%
import os #for listing directories
import pandas #for reading csv file 
import folium # for creating Map
from geopy.geocoders import Nominatim #for getting Lat and Long for the address provided

# %%
os.listdir('./../Jupyter/DataAnalysisPandas/')
# Out:
# ['.ipynb_checkpoints',
#  'DataAnalysis.ipynb',
#  'geoCoding.ipynb',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx']

# %%
data=pandas.read_csv('supermarkets.csv')
data
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
nom = Nominatim();

# %%
data[1:2]
# Out:
#    ID         Address           City     State Country         Name  Employees
# 1   2  735 Dolores St  San Francisco  CA 94119     USA  Bready Shop         15

# %%
data=data.drop(data.index[1]) #dropping because there is no Latitude and Longitude available for this address

# %%
data
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 2         25
# 3         10
# 4         12
# 5         20

# %%
wholeAddress=data['Address']+', '+data['City']+', '+data['State']+', '+data['Country']

# %%
wholeAddress=list(wholeAddress)

# %%
wholeData=[nom.geocode(wholeAddress[i]) for i in range(5)]
print wholeData
# Out:
# [Location((37.7564888776, -122.429343347, 0.0)), Location((37.7557251224, -122.428601306, 0.0)), Location((37.7529648, -122.431714, 0.0)), Location((37.7521458, -122.42981516, 0.0)), Location((37.7536733265, -122.433219959, 0.0))]

# %%
wholeData[0]
# Out:
# Location((37.7564888776, -122.429343347, 0.0))

# %%
Latitude=[wholeData[i].latitude for i in range(5)]
Longitude=[wholeData[i].longitude for i in range(5)]

# %%
Latitude
# Out:
# [37.756488877551, 37.755725122449, 37.7529648, 37.7521458, 37.7536733265306]

# %%
data.to_csv('superMarketsWithLatLong.csv')

# %%
Location = [str(Latitude[i])+', '+ str(Longitude[i]) for i in range(5)]

# %%
LatLong=(list(Location));
LatLong[0]
# Out:
# '37.7564888776, -122.429343347'

# %%
map=folium.Map(location=[LatLong[0]],zoom_start=12,tiles='Stamen Terrain')

# %%
data.index=range(5)
data
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 2   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 3   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 4   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         25
# 2         10
# 3         12
# 4         20

# %%
data['Latitude']=Latitude;
data['Longitude']=Longitude;

# %%
data
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 2   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 3   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 4   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees   Latitude   Longitude
# 0          8  37.756489 -122.429343
# 1         25  37.755725 -122.428601
# 2         10  37.752965 -122.431714
# 3         12  37.752146 -122.429815
# 4         20  37.753673 -122.433220

# %%
data.to_csv('superMarketsWithLatLong.csv');
latMean=data['Latitude'].mean();
LongMean=data['Longitude'].mean();

# %%
map2=folium.Map(location=[latMean,LongMean],zoom_start=5,tiles='Stamen Terrain')
[folium.Marker(location=[LatLong[i]], popup=data['Name'][i]).add_to(map2) for i in range(5)]

# %%
map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Now reading another file for marking Volcanoes
dataVolcanoes=pandas.read_csv('Volcanoes-USA.txt')

# %%
dataVolcanoes
# Out:
#     VOLCANX020    NUMBER                     NAME       LOCATION  \
# 0        509.0  1201-01=                    Baker  US-Washington
# 1        511.0  1201-02-             Glacier Peak  US-Washington
# 2        513.0  1201-03-                  Rainier  US-Washington
# 3        515.0  1201-05-               St. Helens  US-Washington
# 4        516.0  1201-04-                    Adams  US-Washington
# 5        517.0  1201-06-              West Crater  US-Washington
# 6        518.0  1201-07-            Indian Heaven  US-Washington
# 7        519.0  1202-01-                     Hood      US-Oregon
# 8        521.0  1202-02-                Jefferson      US-Oregon
# 9        522.0  1202-03-         Blue Lake Crater      US-Oregon
# 10       523.0  1202-04-      Sand Mountain Field      US-Oregon
# 11       524.0  1202-05-               Washington      US-Oregon
# 12       525.0  1202-06-                  Belknap      US-Oregon
# ...

# %%
[folium.Marker(location=[lat,lon], popup=name,icon = folium.Icon(color ='red')).add_to(map2) \
 for name,lat,lon in zip(dataVolcanoes['NAME'],dataVolcanoes['LAT'],dataVolcanoes['LON'])];

# %%
map2.zoom_start
# Out:
# 10

# %%
map2.save('superMarketsMap2.html')
